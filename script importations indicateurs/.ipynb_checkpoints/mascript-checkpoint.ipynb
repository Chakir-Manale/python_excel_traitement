# %%
import pandas as pd
import openpyxl as xl
import numpy as np
from openpyxl import load_workbook

countries_file = open("inputs\\countries_code.txt","r")
countries = countries_file.readlines() 

row_index = 4
cible_file_name = "this2.xlsx"
wb = load_workbook(filename = cible_file_name)
sheet = wb.active 


source_file_name ="indicateurs\\this2.xls"
excel_data = pd.read_excel(source_file_name, sheet_name='Data',skiprows=3)
country_start = 3
for country in countries:
    df_country = excel_data[excel_data["Country Code"] == country.replace('\n','')]
    print(country)
    print(df_country)
    index_annee = 4
       # sheet.cell(row = 3 , column = column_index).value = indicateur[1]
    for row in range(country_start, country_start+28 ):
        sheet.cell(row = row_index , column = row).value = df_country.iat[0, index_annee]
        index_annee+=1
    row_index+=1
wb.save("this2.xlsx")

print("\n------------ le processus est ternimé -------------\n")
countries_file.close()
input("appuyez sur une touche pour quitter")
# Out:
# SGP
#
#     Country Name Country Code  \
# 206    Singapour          SGP
#
#                                       Indicator Name  Indicator Code  \
# 206  Importations de biens et de services (% du PIB)  NE.IMP.GNFS.ZS
#
#            1960        1961        1962        1963        1964        1965  \
# 206  176.480949  156.978682  148.523307  155.728017  132.946076  134.304196
#
#      ...        2010        2011        2012        2013        2014  \
# 206  ...  171.686595  175.770923  172.493353  171.963984  168.513783
#
#           2015        2016        2017        2018  2019
# 206  151.08679  138.923028  146.411823  149.815982   NaN
#
# [1 rows x 64 columns]
# VNM
#
#     Country Name Country Code  \
# 255     Viet Nam          VNM
#
#                                       Indicator Name  Indicator Code  1960  \
# 255  Importations de biens et de services (% du PIB)  NE.IMP.GNFS.ZS   NaN
#
#      1961  1962  1963  1964  1965  ...       2010       2011       2012  \
# 255   NaN   NaN   NaN   NaN   NaN  ...  80.215013  83.523677  76.525312
#
#           2013       2014       2015       2016       2017        2018  2019
# 255  81.468096  83.129754  88.988166  91.062339  98.791145  102.474861   NaN
#
# [1 rows x 64 columns]
# IND
#
#     Country Name Country Code  \
# 107         Inde          IND
#
#                                       Indicator Name  Indicator Code  \
# 107  Importations de biens et de services (% du PIB)  NE.IMP.GNFS.ZS
#
#          1960      1961      1962      1963      1964      1965  ...  \
# 107  6.833677  5.957576  6.031815  5.906834  5.684998  5.211562  ...
#
#           2010       2011       2012       2013       2014       2015  \
# 107  26.854273  31.083461  31.259291  28.413271  25.954223  22.109725
#
#           2016       2017       2018  2019
# 107  20.964136  21.986068  23.639634   NaN
#
# [1 rows x 64 columns]
# MEX
#
#     Country Name Country Code  \
# 152      Mexique          MEX
#
#                                       Indicator Name  Indicator Code  \
# 152  Importations de biens et de services (% du PIB)  NE.IMP.GNFS.ZS
#
#           1960       1961       1962      1963      1964      1965  ...  \
# 152  11.663681  10.615254  10.108737  9.953585  9.853426  9.522674  ...
#
#           2010       2011       2012       2013       2014       2015  \
# 152  31.062654  32.432971  33.501678  32.459224  33.071035  36.602984
#
#           2016       2017       2018  2019
# 152  39.037305  39.504298  41.159015   NaN
#
# [1 rows x 64 columns]
# CRI
#
#    Country Name Country Code                                   Indicator Name  \
# 46   Costa Rica          CRI  Importations de biens et de services (% du PIB)
#
#     Indicator Code       1960       1961       1962      1963       1964  \
# 46  NE.IMP.GNFS.ZS  26.075859  25.057175  26.049705  27.12825  28.568258
#
#          1965  ...       2010       2011       2012       2013       2014  \
# 46  33.188238  ...  35.045618  36.594486  35.974968  34.285357  34.790543
#
#          2015       2016       2017       2018  2019
# 46  31.693356  31.832023  32.994866  33.242084   NaN
#
# [1 rows x 64 columns]
# BRA
#
#    Country Name Country Code                                   Indicator Name  \
# 27       Brésil          BRA  Importations de biens et de services (% du PIB)
#
#     Indicator Code      1960      1961      1962   1963    1964      1965  \
# 27  NE.IMP.GNFS.ZS  7.117286  7.339459  5.188974  9.111  5.6776  5.555925
#
#     ...       2010       2011       2012       2013       2014       2015  \
# 27  ...  11.906593  12.351895  13.236735  14.043745  13.673463  14.053451
#
#          2016       2017       2018  2019
# 27  12.067019  11.804638  14.508083   NaN
#
# [1 rows x 64 columns]
# RUS
#
#              Country Name Country Code  \
# 200  Fédération de Russie          RUS
#
#                                       Indicator Name  Indicator Code  1960  \
# 200  Importations de biens et de services (% du PIB)  NE.IMP.GNFS.ZS   NaN
#
#      1961  1962  1963  1964  1965  ...       2010       2011       2012  \
# 200   NaN   NaN   NaN   NaN   NaN  ...  21.139945  19.924177  20.226107
#
#          2013      2014       2015       2016       2017       2018  2019
# 200  20.40039  20.68279  20.643292  20.565208  20.708709  20.769323   NaN
#
# [1 rows x 64 columns]
# EGY
#
#                    Country Name Country Code  \
# 65  Égypte, République arabe d’          EGY
#
#                                      Indicator Name  Indicator Code  \
# 65  Importations de biens et de services (% du PIB)  NE.IMP.GNFS.ZS
#
#          1960       1961       1962       1963       1964       1965  ...  \
# 65  21.825505  19.741886  19.518471  23.586927  24.874237  20.132421  ...
#
#          2010       2011       2012       2013       2014       2015  \
# 65  26.587104  24.688207  24.314803  23.355192  22.676056  21.662097
#
#          2016       2017       2018  2019
# 65  19.901085  29.308357  29.366296   NaN
#
# [1 rows x 64 columns]
# IDN
#
#     Country Name Country Code  \
# 104    Indonésie          IDN
#
#                                       Indicator Name  Indicator Code  \
# 104  Importations de biens et de services (% du PIB)  NE.IMP.GNFS.ZS
#
#           1960       1961      1962      1963       1964      1965  ...  \
# 104  12.557663  13.614125  5.392854  9.349289  13.065115  5.735976  ...
#
#           2010      2011      2012       2013       2014       2015  \
# 104  22.402243  23.85266  24.98852  24.713796  24.414191  20.777461
#
#           2016       2017      2018  2019
# 104  18.332348  19.174186  22.05597   NaN
#
# [1 rows x 64 columns]
# ZAF
#
#        Country Name Country Code  \
# 261  Afrique du Sud          ZAF
#
#                                       Indicator Name  Indicator Code  \
# 261  Importations de biens et de services (% du PIB)  NE.IMP.GNFS.ZS
#
#           1960       1961       1962       1963       1964       1965  ...  \
# 261  24.561079  21.299385  20.658979  23.191205  25.519568  26.778656  ...
#
#           2010       2011      2012       2013       2014       2015  \
# 261  27.373752  29.651689  31.17582  33.270419  32.965856  31.464185
#
#          2016       2017       2018  2019
# 261  30.05726  28.346226  29.563251   NaN
#
# [1 rows x 64 columns]
# MAR
#
#     Country Name Country Code  \
# 146        Maroc          MAR
#
#                                       Indicator Name  Indicator Code  \
# 146  Importations de biens et de services (% du PIB)  NE.IMP.GNFS.ZS
#
#          1960       1961       1962       1963       1964      1965  ...  \
# 146  22.69861  24.778066  21.092845  20.078828  19.137069  16.89008  ...
#
#           2010       2011       2012       2013       2014       2015  \
# 146  43.014616  48.726766  50.195369  47.242915  47.139865  42.397996
#
#           2016       2017       2018  2019
# 146  45.509061  46.761888  49.255436   NaN
#
# [1 rows x 64 columns]
# PAN
#
#     Country Name Country Code  \
# 183       Panama          PAN
#
#                                       Indicator Name  Indicator Code  \
# 183  Importations de biens et de services (% du PIB)  NE.IMP.GNFS.ZS
#
#           1960       1961       1962       1963       1964       1965  ...  \
# 183  54.379908  53.668161  57.169552  60.091203  56.944858  58.233614  ...
#
#           2010      2011       2012       2013       2014       2015  \
# 183  78.231879  84.25714  82.867298  72.472368  63.733061  52.251639
#
#           2016       2017  2018  2019
# 183  45.099866  45.307306   NaN   NaN
#
# [1 rows x 64 columns]
# CHL
#
#    Country Name Country Code                                   Indicator Name  \
# 37        Chili          CHL  Importations de biens et de services (% du PIB)
#
#     Indicator Code       1960      1961       1962      1963       1964  \
# 37  NE.IMP.GNFS.ZS  15.833309  15.52468  12.797946  14.76936  13.226814
#
#          1965  ...       2010       2011       2012       2013       2014  \
# 37  12.654002  ...  31.318603  34.443708  34.149988  32.774003  32.161838
#
#          2015       2016       2017       2018  2019
# 37  29.595927  27.550444  27.144958  28.719133   NaN
#
# [1 rows x 64 columns]
# DZA
#
#    Country Name Country Code                                   Indicator Name  \
# 58      Algérie          DZA  Importations de biens et de services (% du PIB)
#
#     Indicator Code       1960       1961       1962       1963       1964  \
# 58  NE.IMP.GNFS.ZS  67.143632  67.503771  20.818647  36.825515  29.439763
#
#          1965  ...       2010       2011       2012       2013       2014  \
# 58  25.833078  ...  31.422519  28.685901  28.514056  30.400831  31.926749
#
#          2015       2016      2017       2018  2019
# 58  36.523342  35.053242  33.21795  32.341022   NaN
#
# [1 rows x 64 columns]
# PER
#
#     Country Name Country Code  \
# 184        Pérou          PER
#
#                                       Indicator Name  Indicator Code  \
# 184  Importations de biens et de services (% du PIB)  NE.IMP.GNFS.ZS
#
#           1960       1961       1962       1963       1964       1965  ...  \
# 184  20.270596  22.200175  21.959928  21.579325  18.799496  18.993026  ...
#
#           2010       2011       2012       2013       2014       2015  \
# 184  23.846645  25.485521  25.170281  24.978843  24.246151  23.875443
#
#           2016       2017       2018  2019
# 184  22.788527  22.793678  23.537045   NaN
#
# [1 rows x 64 columns]
# TUR
#
#     Country Name Country Code  \
# 242      Turquie          TUR
#
#                                       Indicator Name  Indicator Code  \
# 242  Importations de biens et de services (% du PIB)  NE.IMP.GNFS.ZS
#
#          1960      1961      1962      1963      1964     1965  ...  \
# 242  3.671072  6.815021  7.970112  6.974249  5.467197  5.38533  ...
#
#           2010       2011       2012       2013       2014       2015  \
# 242  25.450409  30.400533  28.577944  28.078069  27.649769  25.953935
#
#           2016       2017       2018  2019
# 242  24.850564  29.284516  30.627267   NaN
#
# [1 rows x 64 columns]
# ESP
#
#    Country Name Country Code                                   Indicator Name  \
# 68      Espagne          ESP  Importations de biens et de services (% du PIB)
#
#     Indicator Code  1960  1961  1962  1963  1964  1965  ...       2010  \
# 68  NE.IMP.GNFS.ZS   NaN   NaN   NaN   NaN   NaN   NaN  ...  26.976561
#
#          2011       2012       2013       2014       2015       2016  \
# 68  29.258209  29.390097  29.033722  30.383042  30.586123  29.892534
#
#          2017       2018  2019
# 68  31.599187  32.403033   NaN
#
# [1 rows x 64 columns]
# TUN
#
#     Country Name Country Code  \
# 241      Tunisie          TUN
#
#                                       Indicator Name  Indicator Code  1960  \
# 241  Importations de biens et de services (% du PIB)  NE.IMP.GNFS.ZS   NaN
#
#      1961  1962  1963  1964       1965  ...      2010       2011      2012  \
# 241   NaN   NaN   NaN   NaN  14.395541  ...  54.65177  55.997314  57.98486
#
#           2013       2014       2015       2016       2017       2018  2019
# 241  56.483343  55.901906  51.590819  51.371223  56.942522  62.040046   NaN
#
# [1 rows x 64 columns]
# THA
#
#     Country Name Country Code  \
# 231    Thaïlande          THA
#
#                                       Indicator Name  Indicator Code  \
# 231  Importations de biens et de services (% du PIB)  NE.IMP.GNFS.ZS
#
#           1960       1961       1962       1963      1964       1965  ...  \
# 231  17.415215  17.110096  17.649417  18.375083  18.77521  18.061143  ...
#
#           2010       2011       2012       2013       2014       2015  \
# 231  60.764316  68.820571  68.723725  65.291113  62.511374  57.203038
#
#           2016      2017       2018  2019
# 231  53.635831  54.34739  56.488321   NaN
#
# [1 rows x 64 columns]
# USA
#
#     Country Name Country Code  \
# 249   États-Unis          USA
#
#                                       Indicator Name  Indicator Code  1960  \
# 249  Importations de biens et de services (% du PIB)  NE.IMP.GNFS.ZS   NaN
#
#      1961  1962  1963  1964  1965  ...       2010       2011       2012  \
# 249   NaN   NaN   NaN   NaN   NaN  ...  15.742894  17.258755  17.039265
#
#           2013       2014       2015       2016       2017       2018  2019
# 249  16.468483  16.433076  15.295019  14.643649  15.047486  15.325211   NaN
#
# [1 rows x 64 columns]
# MYS
#
#     Country Name Country Code  \
# 167     Malaisie          MYS
#
#                                       Indicator Name  Indicator Code  \
# 167  Importations de biens et de services (% du PIB)  NE.IMP.GNFS.ZS
#
#           1960       1961       1962       1963       1964      1965  ...  \
# 167  39.260143  41.583648  43.136935  43.987507  42.347624  40.41989  ...
#
#          2010       2011       2012      2013       2014       2015  \
# 167  71.01447  69.682242  68.541841  67.09195  64.518733  61.921371
#
#           2016       2017       2018  2019
# 167  60.123566  63.173934  61.745411   NaN
# [1 rows x 64 columns]
# POL
#
#     Country Name Country Code  \
# 188      Pologne          POL
#
#                                       Indicator Name  Indicator Code  1960  \
# 188  Importations de biens et de services (% du PIB)  NE.IMP.GNFS.ZS   NaN
#
#      1961  1962  1963  1964  1965  ...       2010      2011      2012  \
# 188   NaN   NaN   NaN   NaN   NaN  ...  42.053196  44.51955  44.88387
#
#           2013       2014       2015       2016       2017       2018  2019
# 188  44.372033  46.128003  46.404951  48.158144  50.170712  52.153985   NaN
#
# [1 rows x 64 columns]
# HUN
#
#    Country Name Country Code                                   Indicator Name  \
# 99      Hongrie          HUN  Importations de biens et de services (% du PIB)
#
#     Indicator Code  1960  1961  1962  1963  1964  1965  ...       2010  \
# 99  NE.IMP.GNFS.ZS   NaN   NaN   NaN   NaN   NaN   NaN  ...  76.453891
#
#          2011       2012       2013       2014       2015      2016  \
# 99  80.468352  79.548061  78.592816  81.071764  79.991872  78.40373
#
#          2017       2018  2019
# 99  79.854197  80.565075   NaN
#
# [1 rows x 64 columns]
# ROU
#
#     Country Name Country Code  \
# 199     Roumanie          ROU
#
#                                       Indicator Name  Indicator Code  1960  \
# 199  Importations de biens et de services (% du PIB)  NE.IMP.GNFS.ZS   NaN
#
#      1961  1962  1963  1964  1965  ...       2010       2011       2012  \
# 199   NaN   NaN   NaN   NaN   NaN  ...  38.836889  42.839862  42.533477
#
#           2013       2014       2015       2016       2017       2018  2019
# 199  40.651283  41.603981  41.639486  42.112363  43.594064  44.853054   NaN
#
# [1 rows x 64 columns]
# FRA
#
#    Country Name Country Code                                   Indicator Name  \
# 75       France          FRA  Importations de biens et de services (% du PIB)
#
#     Indicator Code       1960       1961       1962       1963       1964  \
# 75  NE.IMP.GNFS.ZS  12.379895  12.263909  11.960075  12.231558  12.910748
#
#          1965  ...       2010       2011       2012       2013       2014  \
# 75  12.385177  ...  28.079491  30.369239  30.499032  30.399317  30.812112
#
#          2015       2016       2017       2018  2019
# 75  31.159072  30.852605  31.878166  32.110969   NaN
#
# [1 rows x 64 columns]
# CZE
#
#           Country Name Country Code  \
# 52  République tchèque          CZE
#
#                                      Indicator Name  Indicator Code  1960  \
# 52  Importations de biens et de services (% du PIB)  NE.IMP.GNFS.ZS   NaN
#
#     1961  1962  1963  1964  1965  ...       2010       2011       2012  \
# 52   NaN   NaN   NaN   NaN   NaN  ...  62.937556  67.477822  71.367384
#
#          2013       2014       2015       2016       2017       2018  2019
# 52  71.107223  76.181264  75.050563  71.839056  72.202798  72.003071   NaN
#
# [1 rows x 64 columns]
# CHN
#
#    Country Name Country Code                                   Indicator Name  \
# 38        Chine          CHN  Importations de biens et de services (% du PIB)
#
#     Indicator Code     1960     1961      1962      1963     1964      1965  \
# 38  NE.IMP.GNFS.ZS  4.42827  3.48941  2.908277  2.859889  2.86414  3.189158
#
#     ...       2010       2011       2012       2013       2014       2015  \
# 38  ...  23.531742  24.172714  22.774998  22.145122  21.471307  18.185733
#
#          2016       2017       2018  2019
# 38  17.458193  18.186732  18.731314   NaN
#
# [1 rows x 64 columns]
# DEU
#
#    Country Name Country Code                                   Indicator Name  \
# 53    Allemagne          DEU  Importations de biens et de services (% du PIB)
#
#     Indicator Code  1960  1961  1962  1963  1964  1965  ...       2010  \
# 53  NE.IMP.GNFS.ZS   NaN   NaN   NaN   NaN   NaN   NaN  ...  37.303151
#
#          2011       2012       2013      2014       2015       2016  \
# 53  40.148985  40.206935  39.660199  39.00083  39.286551  38.659966
#
#          2017       2018  2019
# 53  40.295964  41.254736   NaN
#
# [1 rows x 64 columns]
# AUT
#
#    Country Name Country Code                                   Indicator Name  \
# 12     Autriche          AUT  Importations de biens et de services (% du PIB)
#
#     Indicator Code  1960  1961  1962  1963  1964  1965  ...       2010  \
# 12  NE.IMP.GNFS.ZS   NaN   NaN   NaN   NaN   NaN   NaN  ...  47.757636
#
#          2011       2012       2013       2014       2015       2016  \
# 12  51.154118  51.178501  50.625121  50.116956  49.338255  48.617591
#
#          2017       2018  2019
# 12  50.735505  52.034407   NaN
#
# [1 rows x 64 columns]
# COL
#
#    Country Name Country Code                                   Indicator Name  \
# 43     Colombie          COL  Importations de biens et de services (% du PIB)
#
#     Indicator Code       1960       1961       1962       1963       1964  \
# 43  NE.IMP.GNFS.ZS  14.757433  13.829797  12.227312  12.350394  12.651621
#
#         1965  ...      2010       2011       2012       2013       2014  \
# 43  9.709364  ...  17.95294  20.223728  20.042662  19.913169  20.852769
#
#          2015       2016       2017       2018  2019
# 43  22.710553  21.485514  20.167921  20.825346   NaN
#
# [1 rows x 64 columns]
# JPN
#     Country Name Country Code  \
# 117        Japon          JPN
#
#                                       Indicator Name  Indicator Code  1960  \
# 117  Importations de biens et de services (% du PIB)  NE.IMP.GNFS.ZS   NaN
#
#      1961  1962  1963  1964  1965  ...       2010       2011       2012  \
# 117   NaN   NaN   NaN   NaN   NaN  ...  13.576251  15.468007  16.091371
#
#           2013       2014       2015       2016       2017       2018  2019
# 117  18.232124  20.005468  18.030045  15.262607  16.839334  18.192864   NaN
#
# [1 rows x 64 columns]
#
# ------------ le processus est ternimé -------------
#
# appuyez sur une touche pour quitter
# ''
